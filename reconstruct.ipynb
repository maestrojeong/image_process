# %%
import matplotlib.pyplot as plt
import numpy as np 
from ops import get_HSV
from ops import HSV2img
from ops import cycle_clip_2d
from ops import clip_2d
from ops import flatten_img
from ops import rgb2gray
from ops import get_mask
from ops import conv
from ops import contrast

# %%
image = plt.imread('./dark.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
H, S, V = get_HSV(image)

# %%
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)
ax1.imshow(H, cmap='gray')
ax1.set_title("H")
ax1.axis('off')
ax2.imshow(S, cmap='gray')
ax2.set_title("S")
ax2.axis('off')
ax3.imshow(V, cmap='gray')
ax3.set_title("V")
ax3.axis('off')
plt.show()

# %%
reconstructed_img = HSV2img(H,S,flatten_img(V))

# %%
plt.imshow(reconstructed_img)
plt.axis('off')
plt.show()
